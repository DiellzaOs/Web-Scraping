# %%
from bs4 import BeautifulSoup
import requests
import smtplib
import time
import datetime

# %%
URL='https://www.amazon.com/Funny-Data-Systems-Business-Analyst/dp/B07FNW9FGJ/ref=sr_1_3?dchild=1&keywords=data%2Banalyst%2Btshirt&qid=1626655184&sr=8-3&customId=B0752XJYNL&th=1'

headers={ "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/124.0.0.0 Safari/537.36",
         "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7", 
         "Accept-Encoding": "gzip, deflate, br, zstd", "Dnt": "1", "Upgrade-Insecure-Requests": "1"}

page =requests.get(URL, headers=headers)

soup1 = BeautifulSoup(page.content,'html.parser')

soup2=BeautifulSoup(soup1.prettify(), 'html.parser')

title = soup2.find(id='productTitle').get_text()

#price = soup2.find('div',class_='a-section a-spacing-none aok-align-center aok-relative')
price = 16.99
rating = soup2.find('span', class_='a-size-base a-color-base').get_text()

product_details = soup2.find(class_='a-fixed-left-grid-col a-col-right').get_text()

print(title)
print(price)
print(rating)
print(product_details)
# Out:
#                     Funny Got Data MIS Data Systems Business Analyst T-Shirt
#
# 16.99
#
#                        4.3
#
#
#
#
#                       Solid colors: 100% Cotton; Heather Grey: 90% Cotton, 10% Polyester; Dark Heather and Heather Blue: 50% Cotton, 50% Polyester; OR Dark Heather, Heather Blue and All Other Heathers: 65% Polyester, 35% Cotton; Girls' Heathers: 60% Cotton, 40% Polyester

# %%
title=title.strip()
rating=rating.strip()
product_details=product_details.strip()

print(title)
print(price)
print(rating)
print(product_details)
# Out:
# Funny Got Data MIS Data Systems Business Analyst T-Shirt
# 16.99
# 4.3
# Solid colors: 100% Cotton; Heather Grey: 90% Cotton, 10% Polyester; Dark Heather and Heather Blue: 50% Cotton, 50% Polyester; OR Dark Heather, Heather Blue and All Other Heathers: 65% Polyester, 35% Cotton; Girls' Heathers: 60% Cotton, 40% Polyester

# %%
today = datetime.date.today()
print(today)
# Out:
# 2024-05-03

# %%
import csv

header=['Product Title', 'Price', 'Rating', 'Product Details', 'Date']
data=[title,price,rating,product_details, today]

with open('AmazonScraperData.csv','w', newline='', encoding='UTF8')as f:
    writer=csv.writer(f)
    writer.writerow(header)
    writer.writerow(data)

# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\Diellza\Desktop\Data Analisys Protfolio Projects\Web Scraping\AmazonScraperData.csv")
df
# Out:
#                                        Product Title  Price  Rating  \
# 0  Funny Got Data MIS Data Systems Business Analy...  16.99     4.3
# 1  Funny Got Data MIS Data Systems Business Analy...  16.99     4.3
#
#                                      Product Details        Date
# 0  Solid colors: 100% Cotton; Heather Grey: 90% C...  2024-05-03
# 1  Solid colors: 100% Cotton; Heather Grey: 90% C...  2024-05-03

# %%
#appending data to the csv

with open('AmazonScraperData.csv','a+', newline='', encoding='UTF8')as f:
    writer=csv.writer(f)
    writer.writerow(data)

# %%
#automating to append data by itself everyday

def check_price():
    URL='https://www.amazon.com/Funny-Data-Systems-Business-Analyst/dp/B07FNW9FGJ/ref=sr_1_3?dchild=1&keywords=data%2Banalyst%2Btshirt&qid=1626655184&sr=8-3&customId=B0752XJYNL&th=1'

    headers={ "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/124.0.0.0 Safari/537.36",
         "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7", 
         "Accept-Encoding": "gzip, deflate, br, zstd", "Dnt": "1", "Upgrade-Insecure-Requests": "1"}

    page =requests.get(URL, headers=headers)

    soup1 = BeautifulSoup(page.content,'html.parser')

    soup2=BeautifulSoup(soup1.prettify(), 'html.parser')

    title = soup2.find(id='productTitle').get_text()

    #price = soup2.find('div',class_='a-section a-spacing-none aok-align-center aok-relative')
    price = 16.99
    rating = soup2.find('span', class_='a-size-base a-color-base').get_text()

    product_details = soup2.find(class_='a-fixed-left-grid-col a-col-right').get_text()

    title=title.strip()
    rating=rating.strip()
    product_details=product_details.strip()
    
    today = datetime.date.today()
    
    
    import csv

    header=['Product Title', 'Price', 'Rating', 'Product Details', 'Date']
    data=[title,price,rating,product_details, today]
    
    
    #appending data to the csv

    with open('AmazonScraperData.csv','a+', newline='', encoding='UTF8')as f:
        writer=csv.writer(f)
        writer.writerow(data)
        
    #this will send an email if the price changes while automating and appending the same product everyday
    if(price<14):
        send_mail()

# %%
#automating to append data by itself everyday
while(True):
    check_price()
    time.sleep(86400)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[52], line 3
#       1 while(True):
#       2     check_price()
# ----> 3     time.sleep(5)
#
# KeyboardInterrupt:

# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\Diellza\Desktop\Data Analisys Protfolio Projects\Web Scraping\AmazonScraperData.csv")
df
# Out:
#                                         Product Title  Price  Rating  \
# 0   Funny Got Data MIS Data Systems Business Analy...  16.99     4.3
# 1   Funny Got Data MIS Data Systems Business Analy...  16.99     4.3
# 2   Funny Got Data MIS Data Systems Business Analy...  16.99     4.3
# 3   Funny Got Data MIS Data Systems Business Analy...  16.99     4.3
# 4   Funny Got Data MIS Data Systems Business Analy...  16.99     4.3
# 5   Funny Got Data MIS Data Systems Business Analy...  16.99     4.3
# 6   Funny Got Data MIS Data Systems Business Analy...  16.99     4.3
# 7   Funny Got Data MIS Data Systems Business Analy...  16.99     4.3
# 8   Funny Got Data MIS Data Systems Business Analy...  16.99     4.3
# 9   Funny Got Data MIS Data Systems Business Analy...  16.99     4.3
# 10  Funny Got Data MIS Data Systems Business Analy...  16.99     4.3
#
#                                       Product Details        Date
# 0   Solid colors: 100% Cotton; Heather Grey: 90% C...  2024-05-03
# ...

# %%
def send_mail():
    server = smtplib.SMTP_SSL('smtp.gmail.com', 465)
    server.ehlo()
    server.ehlo()
    server.login('diellzao37@gmail.com','my password')
    
    subject='The shirt is below $14'
    body='buy it now dont leave it for later'
    
    msg=f"Subject: {subject}\n\n{body}"
    
    sever.sendmail("diellzao37@gmail.com", msg)
